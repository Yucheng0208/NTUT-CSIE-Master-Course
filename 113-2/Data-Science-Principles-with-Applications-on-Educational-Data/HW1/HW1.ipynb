# %% [markdown]
# ## Data Science Principles with Applications on Educational Data, Spring 2025
# ## HW1
# ### Due date: 05/14/2025
#
# ### Student ID: 113598043
# ### Name: 張育丞 Yu-Cheng Chang
#
# ##### This homework set is to practice some common operations for the exploration on the data set and be familiar with the notebook environment. Please go through each question to provide your answer. In the meantime, we use the famous iris data set as an example for your reference. First, please load the working dataset "exam_results" provided with .csv format.

# %% [markdown]
# #### 1. Use `pandas.read_csv('file_path')` to load the dataset
# #### Please use the **exam_results.csv** as the dataset for **df** parameter

# %%
import pandas as pd
import seaborn as sns
iris = sns.load_dataset('iris')

# Load the dataset from the file path
df = pd.read_csv('exam_results.csv')

# %% [markdown]
# #### 2. Use `(pandas_dataset).info()` to show the dataset information

# %%
# Example
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### Problem: Please use the **df** as the dataset to show the dataset information

# %%
# Write Answer here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1734 entries, 0 to 1733
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   school          1734 non-null   int64
#  1   year            1734 non-null   int64
#  2   semester        1734 non-null   int64
#  3   grade           1734 non-null   int64
#  4   class           1734 non-null   int64
#  5   number          1734 non-null   int64
#  6   student_number  1734 non-null   int64
#  7   sex             1734 non-null   object
#  8   chinese_1       1722 non-null   float64
#  9   chinese_2       1722 non-null   float64
#  10  chinese_3       1476 non-null   float64
#  11  math_1          1729 non-null   float64
#  12  math_2          1729 non-null   float64
#  13  math_3          1482 non-null   float64
#  14  english_1       1727 non-null   float64
#  15  english_2       1727 non-null   float64
#  16  english_3       1480 non-null   float64
# ...

# %% [markdown]
# #### 3. Check for missing values
# - df.isna().sum()
# -  df.notnull()

# %%
# Example 1
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Example 2
iris.notnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0            True         True          True         True     True
# 1            True         True          True         True     True
# 2            True         True          True         True     True
# 3            True         True          True         True     True
# 4            True         True          True         True     True
# ..            ...          ...           ...          ...      ...
# 145          True         True          True         True     True
# 146          True         True          True         True     True
# 147          True         True          True         True     True
# 148          True         True          True         True     True
# 149          True         True          True         True     True
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Problem: Please use the **df** as the dataset and check for missing values

# %%
# Write Answer here
df.isna().sum()
# Out:
# school              0
# year                0
# semester            0
# grade               0
# class               0
# number              0
# student_number      0
# sex                 0
# chinese_1          12
# chinese_2          12
# chinese_3         258
# math_1              5
# math_2              5
# math_3            252
# english_1           7
# english_2           7
# english_3         254
# science_1          12
# science_2          12
# science_3         258
# society_1           7
# society_2           7
# society_3         254
# dtype: int64

# %% [markdown]
# #### 4. Use `(pandas_dataset).describe()` to show the statistical summary

# %%
# Example
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #### Problem: Please use the **df** as the dataset to show the statistical summary

# %%
# Write Answer here
df.describe()
# Out:
#             school         year     semester        grade        class  \
# count  1734.000000  1734.000000  1734.000000  1734.000000  1734.000000
# mean      2.163783   110.195502     1.426759     7.809689     1.209343
# std       1.313406     1.184806     0.494749     0.794237     0.406957
# min       1.000000   108.000000     1.000000     7.000000     1.000000
# 25%       1.000000   109.000000     1.000000     7.000000     1.000000
# 50%       2.000000   110.000000     1.000000     8.000000     1.000000
# 75%       3.000000   111.000000     2.000000     8.000000     1.000000
# max       5.000000   112.000000     2.000000     9.000000     2.000000
#
#             number  student_number    chinese_1    chinese_2    chinese_3  \
# count  1734.000000     1734.000000  1722.000000  1722.000000  1476.000000
# mean      9.183391    10951.311995    70.584785    71.391986    71.180217
# std       6.185985      119.763954    17.183328    17.083729    17.521049
# ...

# %% [markdown]
# #### 5. Data Cleaning
# - remove null - `(pandas_dataset).dropna()`
# - remove duplicated data - `(pandas_dataset).drop_duplicates()`
# - remove unecessary columns  - `(pandas_dataset).drop(columns=['col1', 'col2'])`
#
# Example : Use `iris.drop_duplicates()`

# %%
# Example
iris.drop_duplicates()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# #### Problem: Please use `df.drop_duplicates()`

# %%
# Write Answer here
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### 6. Use `(pandas_dataset).query()` to query the data
#
# Example : Query thedata with `species == "virginica"` from 'iris' dataset

# %%
# example
iris.query('species == "virginica"').head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica

# %% [markdown]
# #### Problem: Please query the data with `year == 109` from 'df' dataset

# %%
# Write Answer here
df.query('year == 109')
# Out:
#       school  year  semester  grade  class  number  student_number     sex  \
# 52         1   109         1      8      1       1           10801  Female
# 53         1   109         1      8      1       2           10802  Female
# 54         1   109         1      8      1       3           10803  Female
# 55         1   109         1      8      1       4           10804  Female
# 56         1   109         1      8      1       5           10805  Female
# ...      ...   ...       ...    ...    ...     ...             ...     ...
# 1633       5   109         2      7      1       3           10903  Female
# 1634       5   109         2      7      1       4           10904    Male
# 1635       5   109         2      7      1       5           10905    Male
# 1636       5   109         2      7      1       6           10906    Male
# 1637       5   109         2      7      1       7           10907  Female
#
# ...

# %% [markdown]
# #### 7. Use `(pandas_dataset).columns` to show column names

# %%
# Example
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# #### Problem: Please use the **df** as the dataset and show the column names

# %%
# Write Answer here
df.columns
# Out:
# Index(['school', 'year', 'semester', 'grade', 'class', 'number',
#        'student_number', 'sex', 'chinese_1', 'chinese_2', 'chinese_3',
#        'math_1', 'math_2', 'math_3', 'english_1', 'english_2', 'english_3',
#        'science_1', 'science_2', 'science_3', 'society_1', 'society_2',
#        'society_3'],
#       dtype='object')

# %% [markdown]
# #### 8. Change column name - `(pandas_dataset).rename(columns={  },inplace=True)`
# Example : rename the column name from **species** to **Type** - `'species':'Type'`

# %%
# Example
iris.rename(columns={'species':'Type'},inplace=True)
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'Type'], dtype='object')

# %% [markdown]
# #### Problem: Please rename the column name in **df** dataset
#
# from **number** to **inclass_number** - `'number':'inclass_number'`
# from **year** to **academic_year** - `'year':'academic_year'`

# %%
# Write Answer here
df.rename(columns={'number': 'inclass_number', 'year': 'academic_year'}, inplace=True)
df.columns
# Out:
# Index(['school', 'academic_year', 'semester', 'grade', 'class',
#        'inclass_number', 'student_number', 'sex', 'chinese_1', 'chinese_2',
#        'chinese_3', 'math_1', 'math_2', 'math_3', 'english_1', 'english_2',
#        'english_3', 'science_1', 'science_2', 'science_3', 'society_1',
#        'society_2', 'society_3'],
#       dtype='object')

# %% [markdown]
# #### 9. Query after rename column
# #### Problem:  Please query the data with `academic_year == 111`
#
# (Do this after problem 8. is done)

# %%
# Write Answer here
df.query('academic_year == 111')
# Out:
#       school  academic_year  semester  grade  class  inclass_number  \
# 280        1            111         1      9      1               1
# 281        1            111         1      9      1               2
# 282        1            111         1      9      1               3
# 283        1            111         1      9      1               4
# 284        1            111         1      9      1               5
# ...      ...            ...       ...    ...    ...             ...
# 1712       5            111         2      7      1               7
# 1713       5            111         2      7      1               8
# 1714       5            111         2      7      1               9
# 1715       5            111         2      7      1              10
# 1716       5            111         2      7      1              12
#
#       student_number     sex  chinese_1  chinese_2  ...  math_3  english_1  \
# ...
